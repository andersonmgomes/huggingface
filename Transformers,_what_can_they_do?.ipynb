# %% [markdown]
# <a href="https://colab.research.google.com/github/andersonmgomes/huggingface/blob/main/Transformers%2C_what_can_they_do%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers and Datasets libraries to run this notebook.

# %%
# !pip install datasets transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598048329353333},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# {'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445987105369568, 0.11197440326213837, 0.043426960706710815],
#  'sequence': 'This is a course about the Transformers library'}

# %%
classifier(
    "Save student name is Anderson",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['add', 'get', 'update', 'delete'],
#  'scores': [0.4560087025165558,
#   0.2774689197540283,
#   0.24406616389751434,
#   0.02245626039803028],
#  'sequence': 'Save student name is Anderson'}

# %%
classifier(
    "Please, save a student with name Anderson Martins",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['get', 'add', 'update', 'delete'],
#  'scores': [0.5003803372383118,
#   0.3831368684768677,
#   0.11094176024198532,
#   0.005541007500141859],
#  'sequence': 'Please, save a student with name Anderson Martins'}

# %%
classifier(
    "I want add a student with name Anderson Martins in the system",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['add', 'update', 'get', 'delete'],
#  'scores': [0.6397849321365356,
#   0.2140336036682129,
#   0.14365224540233612,
#   0.0025291978381574154],
#  'sequence': 'I want add a student with name Anderson Martins in the system'}

# %%
classifier(
    "Please, remove the student with name Anderson Martins",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['delete', 'get', 'update', 'add'],
#  'scores': [0.798954963684082,
#   0.14357492327690125,
#   0.043651267886161804,
#   0.013818840496242046],
#  'sequence': 'Please, remove the student with name Anderson Martins'}

# %%
classifier(
    "I need all students",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['get', 'add', 'update', 'delete'],
#  'scores': [0.46579310297966003,
#   0.36179405450820923,
#   0.1659136712551117,
#   0.006499132141470909],
#  'sequence': 'I need all students'}

# %%
classifier(
    "Ok, update name of the student with id=1 to Anderson Martins",
    candidate_labels=["add", "delete", "get", "update"],
)
# Out:
# {'labels': ['update', 'add', 'get', 'delete'],
#  'scores': [0.6719456315040588,
#   0.2951909005641937,
#   0.031984418630599976,
#   0.0008789782878011465],
#  'sequence': 'Ok, update name of the student with id=1 to Anderson Martins'}

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to properly build and deploy a website and get there quickly.\n\n\nThis course will teach you HTML and CSS fundamentals and can be used with your content. We will also show you how to extend the application'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("A entity of type student has as attributes")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "A entity of type student has as attributes type_int where x and y are the number of ints in the current array (so in case the first person in the family of type student doesn't know the exact length of the string x, then"}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to prepare for new challenges - like a full-time job, on-time and on-time.'},
#  {'generated_text': 'In this course, we will teach you how to build a solid library in your language using C++. We also provide a simple library in C++'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilroberta-base (https://huggingface.co/distilroberta-base)
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# [{'score': 0.196198508143425,
#   'sequence': 'This course will teach you all about mathematical models.',
#   'token': 30412,
#   'token_str': ' mathematical'},
#  {'score': 0.040527332574129105,
#   'sequence': 'This course will teach you all about computational models.',
#   'token': 38163,
#   'token_str': ' computational'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("You will <mask> be in my heart.", top_k=10)
# Out:
# No model was supplied, defaulted to distilroberta-base (https://huggingface.co/distilroberta-base)
# [{'score': 0.6027182340621948,
#   'sequence': 'You will always be in my heart.',
#   'token': 460,
#   'token_str': ' always'},
#  {'score': 0.381907194852829,
#   'sequence': 'You will forever be in my heart.',
#   'token': 6000,
#   'token_str': ' forever'},
#  {'score': 0.005300350487232208,
#   'sequence': 'You will ALWAYS be in my heart.',
#   'token': 44171,
#   'token_str': ' ALWAYS'},
#  {'score': 0.0034840861335396767,
#   'sequence': 'You will never be in my heart.',
#   'token': 393,
#   'token_str': ' never'},
#  {'score': 0.001490880618803203,
#   'sequence': 'You will still be in my heart.',
#   'token': 202,
#   'token_str': ' still'},
#  {'score': 0.00146450602915138,
#   'sequence': 'You will truly be in my heart.',
#   'token': 3127,
#   'token_str': ' truly'},
#  {'score': 0.0009025606559589505,
#   'sequence': 'You will soon be in my heart.',
#   'token': 1010,
# ...

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("Are <mask> good?.", top_k=10)
# Out:
# No model was supplied, defaulted to distilroberta-base (https://huggingface.co/distilroberta-base)
# [{'score': 0.1947961300611496,
#   'sequence': 'Are you good?.',
#   'token': 47,
#   'token_str': ' you'},
#  {'score': 0.17497935891151428,
#   'sequence': 'Are they good?.',
#   'token': 51,
#   'token_str': ' they'},
#  {'score': 0.02567710354924202,
#   'sequence': 'Are things good?.',
#   'token': 383,
#   'token_str': ' things'},
#  {'score': 0.02418145164847374,
#   'sequence': 'Are we good?.',
#   'token': 52,
#   'token_str': ' we'},
#  {'score': 0.02143653854727745,
#   'sequence': 'Are these good?.',
#   'token': 209,
#   'token_str': ' these'},
#  {'score': 0.012124968692660332,
#   'sequence': 'Are those good?.',
#   'token': 167,
#   'token_str': ' those'},
#  {'score': 0.007897493429481983,
#   'sequence': 'Are there good?.',
#   'token': 89,
#   'token_str': ' there'},
#  {'score': 0.007768731564283371,
#   'sequence': 'Are ya good?.',
#   'token': 13531,
# ...

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english)
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"
# [{'end': 18,
#   'entity_group': 'PER',
#   'score': 0.9981694,
#   'start': 11,
#   'word': 'Sylvain'},
#  {'end': 45,
#   'entity_group': 'ORG',
#   'score': 0.9796019,
#   'start': 33,
#   'word': 'Hugging Face'},
#  {'end': 57,
#   'entity_group': 'LOC',
# ...

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("Please, save a student with name Paulo Henrique")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english)
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"
# [{'end': 47,
#   'entity_group': 'PER',
#   'score': 0.998956,
#   'start': 33,
#   'word': 'Paulo Henrique'}]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="what are they trying to save?",
    context="Please, save a student with name Paulo Henrique",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# Downloading:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/249M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]
# {'answer': 'a student', 'end': 22, 'score': 0.28786155581474304, 'start': 13}

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil,    electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India continue to encourage and advance the teaching of engineering .'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# [{'translation_text': 'This course is produced by Hugging Face.'}]
